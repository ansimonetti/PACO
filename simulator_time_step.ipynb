# %% [markdown]
# # Importing packages and files

# %%
import json
import graphviz
import requests
from IPython.display import display, SVG
from anytree.exporter import DotExporter
import sys

sys.path.append('simulator/src')

URL = "127.0.0.1"
PORT = 8001

# %%
from src.utils.env import EXPRESSION, IMPACTS, DURATIONS, IMPACTS_NAMES, PROBABILITIES, DELAYS, LOOP_PROBABILITY, LOOP_ROUND, H
import graphviz
from IPython.display import display, SVG

# A string that describing the full BPMN structure.
expression = "T0, (T1 / [C1] T2), (T3 ^ [N1] T4), (T5 || T6)"


bpmn = {
	EXPRESSION: expression,
	H: 0,
	# A dictionary mapping task names to impact vectors (e.g., cost and hours)
	IMPACTS: {"T0": [10, 5], "T1": [4, 2], "T2": [3, 1], "T3": [6, 4],
			  "T4": [2, 6], "T5": [5, 3], "T6": [5, 2]},
	# A dictionary mapping task names to [min_time, max_time] execution time
	DURATIONS: {"T0": [1, 1], "T1": [1, 1], "T2": [1, 1], "T3": [1, 1],
				"T4": [1, 1], "T5": [1, 1], "T6": [1, 1]},
	# A list of names corresponding to the dimensions of the impacts
	IMPACTS_NAMES: ["cost", "hours"],
	# A dictionary mapping nature labels to their execution probabilities for the left child.
	PROBABILITIES: {"N1": 0.8},
	# A dictionary mapping choice to their delay values.
	DELAYS: {"C1": 0},
	LOOP_PROBABILITY : {}, LOOP_ROUND: {}
}

try:
	resp = requests.get(f'http://{URL}:{8000}/create_bpmn', json={'bpmn': bpmn},  headers={"Content-Type": "application/json"})
	resp.raise_for_status()
	parse_tree = resp.json()["parse_tree"]
	display(SVG(graphviz.Source(resp.json()['bpmn_dot']).pipe(format="svg")))

except requests.exceptions.HTTPError as e:
	print(f"HTTP Error ({resp.status_code}):", resp.json())

# %% [markdown]
# # Initialize petri net and execution tree

# %%
response = requests.post(f"http://{URL}:{PORT}/execute", headers={"Content-Type": "application/json"},
                         json={"bpmn": parse_tree})
response_json = response.json()

# %%
parse_tree = response_json['bpmn']
petri_net = response_json['petri_net']
petri_net_dot = response_json['petri_net_dot']
execution_tree = response_json['execution_tree']
spin_svg = response_json.get('spin_svg')

# %%
graph = graphviz.Source(petri_net_dot, format="svg")
display(graph)
if spin_svg:
    display(SVG(spin_svg))

# %% [markdown]
# # Execute choice

# %%
# Simulate for N seconds (1s per step)
steps = 10
for step in range(steps):
    request_json = {
        'bpmn': parse_tree,
        'petri_net': petri_net,
        'execution_tree': execution_tree,
        'time_step': 1.0,
        # 'choices': ['6']  # opzionale: transizioni stop da eseguire
    }

    response = requests.post(
        f"http://{URL}:{PORT}/execute",
        headers={"Content-Type": "application/json"},
        json=request_json,
    )
    response_json = response.json()
    if response_json.get('type') == 'error':
        raise RuntimeError(response_json.get('message', 'Unknown error'))

    parse_tree = response_json['bpmn']
    petri_net = response_json['petri_net']
    petri_net_dot = response_json['petri_net_dot']
    execution_tree = response_json['execution_tree']
    spin_svg = response_json.get('spin_svg')

    print(f"step {step + 1}/{steps}: current_node={execution_tree['current_node']}")
    graph = graphviz.Source(petri_net_dot, format="svg")
    display(graph)
    if spin_svg:
        display(SVG(spin_svg))
# Out:
# step 1/10: current_node=1
# step 2/10: current_node=2
# step 3/10: current_node=3
# step 4/10: current_node=4
# step 5/10: current_node=4
# step 6/10: current_node=4
# step 7/10: current_node=4
# step 8/10: current_node=4
# step 9/10: current_node=4
# step 10/10: current_node=4

# %%
parse_tree = response_json['bpmn']
petri_net = response_json['petri_net']
petri_net_dot = response_json['petri_net_dot']
execution_tree = response_json['execution_tree']
spin_svg = response_json.get('spin_svg')

# %%
graph = graphviz.Source(petri_net_dot, format="svg")
display(graph)
if spin_svg:
    display(SVG(spin_svg))

# %%
from model.endpoints.execute.request import ExecuteRequest

model = ExecuteRequest.model_validate_json(response.text)
extree = model.execution_tree_obj
extree_dot = "\n".join(DotExporter(extree.root))
display(graphviz.Source(extree_dot))
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 339, in execution_tree_obj
#     logger.debug("Converting execution tree to an ExTree model")
# Message: 'Converting execution tree to an ExTree model'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 342, in convert_node
#     logger.debug("Converting node %s, parent %s", node.name, parent.name if parent else None)
# Message: 'Converting node %s, parent %s'
# Arguments: ('Root', None)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 243, in petri_net_obj
#     logger.debug("Converting PetriNet request to PetriNet model")
# Message: 'Converting PetriNet request to PetriNet model'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 252, in petri_net_obj
#     logger.debug("Converting transition %s", transition)
# Message: 'Converting transition %s'
# Arguments: (TransitionModel(id='24', label='T4', region_id=9, region_type=<RegionType.TASK: 'task'>, probability=1, stop=False, duration=1.0, impacts=[2.0, 6.0]),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 264, in petri_net_obj
#     logger.debug("Transition added: %s", net_transition)
# Message: 'Transition added: %s'
# Arguments: ((24, 'T4'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 252, in petri_net_obj
#     logger.debug("Converting transition %s", transition)
# Message: 'Converting transition %s'
# Arguments: (TransitionModel(id='7', label='T1', region_id=5, region_type=<RegionType.TASK: 'task'>, probability=1, stop=False, duration=1.0, impacts=[4.0, 2.0]),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 264, in petri_net_obj
#     logger.debug("Transition added: %s", net_transition)
# Message: 'Transition added: %s'
# Arguments: ((7, 'T1'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 252, in petri_net_obj
#     logger.debug("Converting transition %s", transition)
# Message: 'Converting transition %s'
# Arguments: (TransitionModel(id='12', label='T2', region_id=6, region_type=<RegionType.TASK: 'task'>, probability=1, stop=False, duration=1.0, impacts=[3.0, 1.0]),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 264, in petri_net_obj
#     logger.debug("Transition added: %s", net_transition)
# Message: 'Transition added: %s'
# Arguments: ((12, 'T2'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 252, in petri_net_obj
#     logger.debug("Converting transition %s", transition)
# Message: 'Converting transition %s'
# Arguments: (TransitionModel(id='14', label='C1', region_id=4, region_type=<RegionType.CHOICE: 'choice'>, probability=1, stop=False, duration=0.0, impacts=None),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
# ...
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   [Previous line repeated 1 more time]
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 296, in petri_net_obj
#     add_arc_from_to(source, target, petri_net)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\utils\net_utils.py", line 29, in add_arc_from_to
#     logger.debug("Adding arc from %s to %s", fr, to)
# Message: 'Adding arc from %s to %s'
# Arguments: (22, (24, 'T4'))
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 367, in execution_tree_obj
#     root = convert_node(self.execution_tree.root)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 363, in convert_node
#     convert_node(child, parent=current_node)
#   [Previous line repeated 1 more time]
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 348, in convert_node
#     marking=model_to_marking(self.petri_net_obj, node.snapshot.marking),
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 25, in model_to_marking
#     logger.debug("Creating marking from model: %s", marking_model)
# Message: 'Creating marking from model: %s'
# Arguments: {'5': {'token': 0, 'age': 0, 'visit_count': 1}, '35': {'token': 0, 'age': 0, 'visit_count': 1}, '34': {'token': 0, 'age': 0, 'visit_count': 1}, '17': {'token': 0, 'age': 0, 'visit_count': 1}, '15': {'token': 0, 'age': 0, 'visit_count': 1}, '0': {'token': 0, 'age': 0, 'visit_count': 1}, '18': {'token': 0, 'age': 0, 'visit_count': 1}, '27': {'token': 0, 'age': 0, 'visit_count': 1}, '32': {'token': 0, 'age': 0, 'visit_count': 1}, '28': {'token': 1, 'age': 0.0, 'visit_count': 0}, '3': {'token': 0, 'age': 0, 'visit_count': 1}, '6': {'token': 0, 'age': 0, 'visit_count': 1}, '31': {'token': 0, 'age': 0, 'visit_count': 1}}
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 371, in execution_tree_obj
#     if not ex_tree.set_current(self.execution_tree.current_node):
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\extree\tree.py", line 183, in set_current
#     logger.debug(f"Setting current node to {node}")
# Message: 'Setting current node to 4'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python313\Lib\logging\handlers.py", line 80, in emit
#     self.doRollover()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Python313\Lib\logging\handlers.py", line 185, in doRollover
#     self.rotate(self.baseFilename, dfn)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python313\Lib\logging\handlers.py", line 121, in rotate
#     os.rename(source, dest)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 32] Impossibile accedere al file. Il file è utilizzato da un altro processo: 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log' -> 'C:\\Users\\danie\\Projects\\GitHub\\PACO\\logs\\detailed.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\danie\Projects\GitHub\PACO\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_48660\2499055934.py", line 4, in <module>
#     extree = model.execution_tree_obj
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\endpoints\execute\request.py", line 371, in execution_tree_obj
#     if not ex_tree.set_current(self.execution_tree.current_node):
#   File "C:\Users\danie\Projects\GitHub\PACO\simulator/src\model\extree\tree.py", line 192, in set_current
#     logger.debug(f"Current node set to {node}")
# Message: "Current node set to (self.name='4', self.id='4')"
# Arguments: ()

# %% [markdown]
# # Display BPMN

# %%
from dot import get_active_region_by_pn

impacts_names = ["a", "b"]
marking = {"21": {"token": 1}, "7": {"token": 1}}

resp = requests.get(f"http://{URL}:{8000}/create_bpmn",
					json={
						"bpmn": bpmn,
						"active_regions": list(get_active_region_by_pn(petri_net, marking)),
						"is_initial": False,
						"is_final": False
					},
					headers={"Content-Type": "application/json"})
resp.raise_for_status()

dot =  resp.json()["bpmn_dot"]
graph = graphviz.Source(dot, format="svg")

display(graph)

# %% [markdown]
# # Display Execution Tree

# %%
from src.paco.parser.dot.execution_tree import get_path_to_current_node, get_execution_tree_dot

current_path = get_path_to_current_node(execution_tree.get("root",{}), execution_tree.get("current_node"))
dot = get_execution_tree_dot(execution_tree.get("root", {}), impacts_names, current_path)
graph = graphviz.Source(dot, format="svg")
display(graph)
